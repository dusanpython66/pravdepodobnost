# %% [markdown]
# ## Popisná statistika

# %%
# Příklad 1: 
# Uvažujme náhodný výběr mající třicet náhodně vybraných prvků: 
import random, math 
import matplotlib.pyplot as plt
L = random.choices([n for n in range(1,6)], k=30)
print(L)
plt.hist(L, bins = 5)
# Out:
# [4, 1, 2, 1, 2, 4, 5, 1, 4, 2, 1, 1, 5, 4, 1, 2, 5, 1, 2, 3, 1, 4, 3, 1, 3, 5, 1, 1, 2, 5]
# (array([11.,  6.,  3.,  5.,  5.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <a list of 5 Patch objects>)

# %%
plt.plot(L)

# %%
x = [1,1,2,3,3,5,7,8,9,10,
     10,11,11,13,13,15,16,17,18,18,
     18,19,20,21,21,23,24,24,25,25,
     25,25,26,26,26,27,27,27,27,27,
     29,30,30,31,33,34,34,34,35,36,
     36,37,37,38,38,39,40,41,41,42,
     43,44,45,45,46,47,48,48,49,50,
     51,52,53,54,55,55,56,57,58,60,
     61,63,64,65,66,68,70,71,72,74,
     75,77,81,83,84,87,89,90,90,91
     ]
# plt.style.use('ggplot')
plt.hist(x, bins=10, color="green")
# Out:
# (array([ 9., 12., 19., 11., 13., 10.,  8.,  7.,  4.,  7.]),
#  array([ 1., 10., 19., 28., 37., 46., 55., 64., 73., 82., 91.]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x)

# %% [markdown]
# ##Strugesovo pravidlo:##
# Počet intervalů lze určit dosazením počtu pozorování do výrazu:
# \begin{equation}
# 1+3.3\log(n)
# \end{equation}

# %%
from math import log
n = 30

print(1 + 3.3*log(n))
# Out:
# 12.223951359485113

# %% [markdown]
# Alternativně lze určit počet intervalů pomocí vzorců:
#
#
# n = počet pozorování
#
# Range = maximální hodnota znaku – minimální hodnota znaku
#
# počet intervalů =  $\sqrt{n}$
#
# Šířka intervalů =  Range / (počet intervalů)

# %%
from math import  *
n = 30
rozsah = 5 - 1
pocet_intervalu = sqrt(n)
sirka_intervalu = rozsah/pocet_intervalu

# %%
sirka_intervalu
# Out:
# 0.7302967433402214

# %%
from pandas import DataFrame

Auta = {'Značka': ['Honda Civic','Ford Focus','Toyota Corolla','Toyota Corolla','Audi A4'],
        'Cena': [22000,27000,22000,29000,35000],
         'Rok': [2014,2015,2016,2017,2018]
        }

df = DataFrame(Auta,columns= ['Značka', 'Cena', 'Rok'])

print (df)
# Out:
#            Značka   Cena   Rok
# 0     Honda Civic  22000  2014
# 1      Ford Focus  27000  2015
# 2  Toyota Corolla  22000  2016
# 3  Toyota Corolla  29000  2017
# 4         Audi A4  35000  2018

# %%
min1 = df['Cena'].min()

# %%
min1
# Out:
# 22000

# %%
df['Cena'].median()
# Out:
# 27000.0

# %% [markdown]
# https://en.wikipedia.org/wiki/File:Finding_the_median.png

# %%
df['Cena'].skew()
# Out:
# 0.7021331831427889

# %% [markdown]
# https://en.wikipedia.org/wiki/Skewness

# %%
df['Rok'].mode()
# Out:
# 0    2014
# 1    2015
# 2    2016
# 3    2017
# 4    2018
# dtype: int64

# %%
stats_numeric = DataFrame.describe(df['Cena']).astype (int)
print (stats_numeric)
# Out:
# count        5
# mean     27000
# std       5431
# min      22000
# 25%      22000
# 50%      27000
# 75%      29000
# max      35000
# Name: Cena, dtype: int64

# %%
A = [22000,27000,22000,29000,35000]
print(plt.hist(A, bins=6))
# Out:
# (array([2., 0., 1., 1., 0., 1.]), array([22000.        , 24166.66666667, 26333.33333333, 28500.        ,
#        30666.66666667, 32833.33333333, 35000.        ]), <a list of 6 Patch objects>)

# %% [markdown]
# ## Binomické rozdělení pravděpodobností

# %%
# Spočtěme P(A_k) pro n = 20, k = 0,1,..., 20
import math as m
import matplotlib.pyplot as plt

n = 200
p = 1/2
q = 1 - p
L = []
for k in range(200):
  Pravd = (m.factorial(n))/(m.factorial(n-k)*m.factorial(k)) * p**k * q**(n-k)
  L.append(Pravd)
  print(Pravd)
print(L)
# Out:
# 6.223015277861142e-61
# 1.2446030555722283e-58
# 1.2383800402943672e-56
# 8.173308265942824e-55
# 4.0253543209768406e-53
# 1.5779388938229215e-51
# 5.128301404924495e-50
# 1.421272103650503e-48
# 3.428818950056838e-47
# 7.314813760121255e-46
# 1.3971294281831597e-44
# 2.413223557770912e-43
# 3.8008271034891865e-42
# 5.49658073427667e-41
# 7.3418614093552665e-40
# 9.10390814760053e-39
# 1.0526393795663114e-37
# 1.1393273284717723e-36
# 1.1583161172796351e-35
# 1.1095449123415453e-34
# 1.0041381456690984e-33
# 8.606898391449415e-33
# 7.002885509406569e-32
# 5.4196244377146496e-31
# 3.996973022814554e-30
# 2.8138690080614457e-29
# 1.8939502938875117e-28
# 1.2205457449497297e-27
# 7.54122906701083e-27
# 4.4727289638822855e-26
# 2.549455509412903e-25
# 1.3980885051619144e-24
# 7.383654917886361e-24
# 3.758951594560329e-23
# 1.8463085773281616e-22
# 8.75677782389928e-22
# 4.01352316928717e-21
# 1.7789670263867457e-20
# 7.630832244764199e-20
# 3.169730317055898e-19
# 1.275816452614999e-18
# 4.978795912643898e-18
# 1.88482988121519e-17
# 6.925653982139536e-17
# 2.4711992618088797e-16
# 8.566824107604116e-16
# 2.886647253649213e-15
# 9.458376107701678e-15
# 3.01485738432991e-14
# 9.352210661594821e-14
# 2.824367619801636e-13
# 8.306963587651871e-13
# 2.380264566461786e-12
# 6.646776525214044e-12
# 1.8094002763082677e-11
# 4.8031352789274014e-11
# 1.243668956150845e-10
# 3.1419005208021344e-10
# 7.746409904736298e-10
# 1.8643901804619564e-09
# 4.3813169240855975e-09
# 1.0055481465114486e-08
# 2.2543740704046993e-08
# 4.938152725648389e-08
# 1.0570733178341082e-07
# 2.211722634237519e-07
# 4.523978115485834e-07
# 9.047956230971668e-07
# 1.7696737922341644e-06
# 3.3854629068827493e-06
# 6.335652011452002e-06
# 1.1600489598433245e-05
# 2.078421053052623e-05
# 3.6443547231607634e-05
# 6.254500673532662e-05
# 0.00010507561131534872
# 0.0001728217291370867
# 0.00027831031705193184
# 0.0004388739615049694
# 0.0006777547253621046
# 0.0010251040221101832
# 0.0015186726253484197
# 0.002203927346542219
# 0.0031332942999033955
# 0.004364231346294015
# 0.005955892190236538
# 0.00796427444043258
# 0.010435945818497864
# 0.013400703153298393
# 0.01686380621538674
# 0.020798694332310314
# 0.02514127886323225
# 0.029786949957525163
# 0.03459129672486793
# 0.0393751994634135
# 0.043934433085492955
# 0.04805328618725792
# 0.051521049107987875
# 0.05414967406247705
# 0.055790573276491506
# 0.05634847900925642
# 0.055790573276491506
# 0.05414967406247705
# 0.051521049107987875
# 0.04805328618725792
# 0.043934433085492955
# 0.0393751994634135
# 0.03459129672486793
